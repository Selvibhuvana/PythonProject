# %%
print("Starting test...")
print("importing src file...")
# Out:
# Starting test...
# importing src file...

# %%
import pandas as pd
df= pd.read_excel(r"S:\Upskilling\Automation testing\python panda automation\emp_excel.xlsx")

# %%
print("Finding duplicates..loading into file")

# %%
dups=df[df.duplicated()]
dups.to_csv(r"S:\Upskilling\Automation testing\python panda automation\dups_in_file.csv")

# %%
print("Finding nulls..field:job")

# %%
df[df['job'].isnull()]
# Out:
#    eno  ename  job country     sal
# 9    6  Peter  NaN  Canada  8000.0

# %%
print("Finding nulls..fields:job,sal...loading into file")

# %%
df[df[['job','sal']].isnull().any(axis=1)].to_csv(r"S:\Upskilling\Automation testing\python panda automation\null_values.csv")

# %%
print("displaying counts ...")
df.count()
# Out:
# displaying counts ...
# eno        10
# ename      10
# job         9
# country    10
# sal         9
# dtype: int64

# %%
print("Test Completed

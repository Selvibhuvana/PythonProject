# %%
import pandas as pd
df_csv = pd.read_csv(r"C:\Users\selvi\Downloads\finance.csv")

# %%
#df_csv.head(5)
#len(df_csv.columns)   #count of columns
#len(df_csv)            #count of rows
df_csv['Year'].unique()
# Out:
# array([1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
df_csv[df_csv.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
df_csv[df_csv['Year'].duplicated()]
# Out:
#         State  Year  Totals.Capital outlay  Totals.Revenue  \
# 21     ALASKA  1992                 389682         6327318
# 22     ALASKA  1993                 428896         7358035
# 23     ALASKA  1994                 502363         6203364
# 24     ALASKA  1995                 410937         8288036
# 25     ALASKA  1996                 447790         8253549
# ...       ...   ...                    ...             ...
# 1046  WYOMING  2015                 467279         7983068
# 1047  WYOMING  2016                 484691         6453279
# 1048  WYOMING  2017                 475405         7000634
# 1049  WYOMING  2018                 513325         7652548
# 1050  WYOMING  2019                 518769         6131182
#
#       Totals.Expenditure  Totals.General expenditure  Totals.General revenue  \
# 21               5254925                     4788127                 5342507
# 22               5423008                     4933907                 6159665
# ...

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_excel = pd.read_excel(r"C:\Users\selvi\Downloads\emp_excel.xlsx")

# %%
#df_excel['sal'].nlargest(2)
df_excel['sal'].nsmallest(3)
# Out:
# 5     500
# 0    1000
# 4    2000
# Name: sal, dtype: int64

# %%
filt = df_excel[df_excel['sal']>4000]
filt
# Out:
#    eno   ename       job country   sal
# 2    3  Mayank        IT   India  7000
# 6    5  Martin  Business      UK  7600

# %%
grp = df_excel.groupby('job')
#grp['eno'].count().rename('emp_cnt')   # this only provides a series considering job as index
#grp['eno'].count().reset_index(name= 'emp_cnt')  # this resets the index to numeric and renames the agg column
grp[['eno']].count()
# Out:
#           eno
# job
# Business    2
# Finance     3
# IT          2

# %%
grp = df_excel.groupby(['job','country'])
grp[['eno']].count()
# Out:
#                     eno
# job      country
# Business UK           2
# Finance  HongKong     1
#          Singapore    2
# IT       India        1
#          US           1

# %%
grp = df_excel.groupby(['job','country'])
grp.get_group(('IT','US'))
# Out:
#    eno    ename job country   sal
# 0    1  Richard  IT      US  1000
